# %%
import pandas as pd

# %%
# !wget -O propertydata.csv https://raw.githubusercontent.com/sathannan/DataScienceTraining/master/property%20data.csv
# Out:
# --2019-03-26 14:57:47--  https://raw.githubusercontent.com/sathannan/DataScienceTraining/master/property%20data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.48.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.48.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 356 [text/plain]
# Saving to: ‘propertydata.csv’
#
# 100%[======================================>] 356         --.-K/s   in 0s
#
# 2019-03-26 14:57:47 (81.5 MB/s) - ‘propertydata.csv’ saved [356/356]

# %%
df=pd.read_csv('propertydata.csv')
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            1        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
df=pd.read_csv('propertydata.csv',na_values=["na","--"])
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY           12           1.0      NaN   700.0
# 4          NaN   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
df.iloc[4,0]=100005000.0
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY           12           1.0      NaN   700.0
# 4  100005000.0   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
df.iloc[1,6]=850
df.iloc[7,6]=850
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5   850.0
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY           12           1.0      NaN   700.0
# 4  100005000.0   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1   850.0
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
df.dropna()
# Out:
#            PID  ST_NUM    ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0     PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0  LEXINGTON            N           3.0      1.5   850.0
# 4  100005000.0   203.0   BERKELEY            Y           3.0        2  1600.0
# 7  100008000.0   213.0    TREMONT            Y           1.0        1   850.0

# %%
df['SQ_FT'].fillna(580,inplace=True)
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5   850.0
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY           12           1.0      NaN   700.0
# 4  100005000.0   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1   850.0
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5   850.0
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY           12           1.0      NaN   700.0
# 4  100005000.0   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1   850.0
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7ed0097d7e9e> in <module>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
df=pd.read_csv("propertydata.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-b743492f132a> in <module>()
# ----> 1 df=pd.read_csv("propertydata.csv")
#
# ...

# %%
# !wget -O propertydata.csv https://raw.githubusercontent.com/sathannan/DataScienceTraining/master/property%20data.csv
# Out:
# --2019-03-28 11:45:29--  https://raw.githubusercontent.com/sathannan/DataScienceTraining/master/property%20data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 199.232.8.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|199.232.8.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 356 [text/plain]
# Saving to: ‘propertydata.csv’
#
# 100%[======================================>] 356         --.-K/s   in 0s
#
# 2019-03-28 11:45:30 (38.2 MB/s) - ‘propertydata.csv’ saved [356/356]

# %%
df=pd.read_csv("propertydata.csv")

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            1        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
df=pd.read_csv('propertydata.csv',na_values=["na","--"])

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY           12           1.0      NaN   700.0
# 4          NaN   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
df['SQ_FT'].mean()
# Out:
# 1100.0

# %%
median=df['SQ_FT'].median()

# %%
df['SQ_FT'].fillna(median,inplace=True)

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5   950.0
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY           12           1.0      NaN   700.0
# 4          NaN   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1   950.0
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
df.sort_values(by='SQ_FT')
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 3  100004000.0   201.0    BERKELEY           12           1.0      NaN   700.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5   950.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1   950.0
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 4          NaN   203.0    BERKELEY            Y           3.0        2  1600.0
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
df['SQ_FT'].plot.bar()

# %%
df=pd.DataFrame(df['SQ_FT'])
hist=df.hist()

# %%
df=pd.DataFrame(df['SQ_FT'])
hist=df.hist(bins=100)

# %%
# !wget O house_prices.csv https://github.com/sathannan/DataScienceTraining/raw/master/house_prices.csv
# Out:
# --2019-03-29 12:46:49--  http://o/
# Resolving o (o)... failed: Name or service not known.
# wget: unable to resolve host address ‘o’
# --2019-03-29 12:46:49--  http://house_prices.csv/
# Resolving house_prices.csv (house_prices.csv)... failed: Name or service not known.
# wget: unable to resolve host address ‘house_prices.csv’
# --2019-03-29 12:46:49--  https://github.com/sathannan/DataScienceTraining/raw/master/house_prices.csv
# Resolving github.com (github.com)... 192.30.253.112, 192.30.253.113
# Connecting to github.com (github.com)|192.30.253.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/sathannan/DataScienceTraining/master/house_prices.csv [following]
# --2019-03-29 12:46:49--  https://raw.githubusercontent.com/sathannan/DataScienceTraining/master/house_prices.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 199.232.8.133
# ...

# %%
ls
# Out:
# house_prices.csv

# %%
import pandas as pd
import math
df=pd.read_csv('house_prices.csv')
df.head(10)
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
# 5  Super built-up  Area  Ready To Move                Whitefield      2 BHK
# 6  Super built-up  Area         18-May          Old Airport Road      4 BHK
# 7  Super built-up  Area  Ready To Move              Rajaji Nagar      4 BHK
# 8  Super built-up  Area  Ready To Move              Marathahalli      3 BHK
# 9            Plot  Area  Ready To Move              Gandhi Bazar  6 Bedroom
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# ...

# %%
meanv=df['price'].mean()

# %%
meanv
# Out:
# 112.56562650150138

# %%
minv=df['price'].min()
minv
# Out:
# 8.0

# %%
df.sort_values(by='price')
# Out:
#                   area_type          availability               location  \
# 10526  Super built-up  Area         Ready To Move     Yelahanka New Town
# 11569            Plot  Area  Immediate Possession             Hosur Road
# 8594         Built-up  Area         Ready To Move             Chandapura
# 5410   Super built-up  Area         Ready To Move               Attibele
# 4113   Super built-up  Area                18-Jan             BTM Layout
# 1471         Built-up  Area                18-Mar                Kengeri
# 11091        Built-up  Area         Ready To Move               Attibele
# 7482   Super built-up  Area         Ready To Move                   Alur
# 12579  Super built-up  Area         Ready To Move             Chandapura
# 11945  Super built-up  Area         Ready To Move               Attibele
# 2437         Built-up  Area         Ready To Move               Attibele
# 8653             Plot  Area         Ready To Move          Doddaballapur
# ...

# %%
df.head(1000)
# Out:
#                 area_type   availability                  location       size  \
# 0    Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1              Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2          Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3    Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4    Super built-up  Area  Ready To Move                  Kothanur      2 BHK
# 5    Super built-up  Area  Ready To Move                Whitefield      2 BHK
# 6    Super built-up  Area         18-May          Old Airport Road      4 BHK
# 7    Super built-up  Area  Ready To Move              Rajaji Nagar      4 BHK
# 8    Super built-up  Area  Ready To Move              Marathahalli      3 BHK
# 9              Plot  Area  Ready To Move              Gandhi Bazar  6 Bedroom
# 10   Super built-up  Area         18-Feb                Whitefield      3 BHK
# ...

# %%
few.head(100)
# Out:
#                   area_type          availability                   location  \
# 10526  Super built-up  Area         Ready To Move         Yelahanka New Town
# 11569            Plot  Area  Immediate Possession                 Hosur Road
# 8594         Built-up  Area         Ready To Move                 Chandapura
# 5410   Super built-up  Area         Ready To Move                   Attibele
# 4113   Super built-up  Area                18-Jan                 BTM Layout
# 1471         Built-up  Area                18-Mar                    Kengeri
# 11091        Built-up  Area         Ready To Move                   Attibele
# 7482   Super built-up  Area         Ready To Move                       Alur
# 12579  Super built-up  Area         Ready To Move                 Chandapura
# 11945  Super built-up  Area         Ready To Move                   Attibele
# 2437         Built-up  Area         Ready To Move                   Attibele
# ...

# %%
few=df.sort_values(by='price')
few
# Out:
#                   area_type          availability               location  \
# 10526  Super built-up  Area         Ready To Move     Yelahanka New Town
# 11569            Plot  Area  Immediate Possession             Hosur Road
# 8594         Built-up  Area         Ready To Move             Chandapura
# 5410   Super built-up  Area         Ready To Move               Attibele
# 4113   Super built-up  Area                18-Jan             BTM Layout
# 1471         Built-up  Area                18-Mar                Kengeri
# 11091        Built-up  Area         Ready To Move               Attibele
# 7482   Super built-up  Area         Ready To Move                   Alur
# 12579  Super built-up  Area         Ready To Move             Chandapura
# 11945  Super built-up  Area         Ready To Move               Attibele
# 2437         Built-up  Area         Ready To Move               Attibele
# 8653             Plot  Area         Ready To Move          Doddaballapur
# ...

# %%
Fetch=few.head(1000)

# %%
Fetch.hist(bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff2817dbf60>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff28c0bcd30>]], dtype=object)

# %%
df['size'].head(50)
# Out:
# 0         2 BHK
# 1     4 Bedroom
# 2         3 BHK
# 3         3 BHK
# 4         2 BHK
# 5         2 BHK
# 6         4 BHK
# 7         4 BHK
# 8         3 BHK
# 9     6 Bedroom
# 10        3 BHK
# 11    4 Bedroom
# 12        2 BHK
# 13        2 BHK
# 14    3 Bedroom
# 15        2 BHK
# 16        3 BHK
# 17        3 BHK
# 18        3 BHK
# 19        2 BHK
# 20        1 BHK
# 21        3 BHK
# 22    4 Bedroom
# 23        3 BHK
# 24         1 RK
# 25        3 BHK
# 26        2 BHK
# 27        3 BHK
# 28        2 BHK
# 29        3 BHK
# 30        4 BHK
# 31        3 BHK
# 32        3 BHK
# 33        3 BHK
# 34        3 BHK
# 35        2 BHK
# 36        2 BHK
# 37        3 BHK
# 38        3 BHK
# 39        2 BHK
# 40        2 BHK
# 41        3 BHK
# 42        1 BHK
# 43    1 Bedroom
# 44        2 BHK
# 45    8 Bedroom
# 46        2 BHK
# 47        2 BHK
# 48    2 Bedroom
# 49        2 BHK
# Name: size, dtype: object

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# 5      Super built-up  Area  Ready To Move                Whitefield
# 6      Super built-up  Area         18-May          Old Airport Road
# 7      Super built-up  Area  Ready To Move              Rajaji Nagar
# 8      Super built-up  Area  Ready To Move              Marathahalli
# 9                Plot  Area  Ready To Move              Gandhi Bazar
# 10     Super built-up  Area         18-Feb                Whitefield
# 11               Plot  Area  Ready To Move                Whitefield
# 12     Super built-up  Area  Ready To Move        7th Phase JP Nagar
# ...

# %%
import pandas as pd
import math
df=pd.read_csv('house_prices.csv')
df.head(10)
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
# 5  Super built-up  Area  Ready To Move                Whitefield      2 BHK
# 6  Super built-up  Area         18-May          Old Airport Road      4 BHK
# 7  Super built-up  Area  Ready To Move              Rajaji Nagar      4 BHK
# 8  Super built-up  Area  Ready To Move              Marathahalli      3 BHK
# 9            Plot  Area  Ready To Move              Gandhi Bazar  6 Bedroom
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df['size'].head(50)
# Out:
# 0         2 BHK
# 1     4 Bedroom
# 2         3 BHK
# 3         3 BHK
# 4         2 BHK
# 5         2 BHK
# 6         4 BHK
# 7         4 BHK
# 8         3 BHK
# 9     6 Bedroom
# 10        3 BHK
# 11    4 Bedroom
# 12        2 BHK
# 13        2 BHK
# 14    3 Bedroom
# 15        2 BHK
# 16        3 BHK
# 17        3 BHK
# 18        3 BHK
# 19        2 BHK
# 20        1 BHK
# 21        3 BHK
# 22    4 Bedroom
# 23        3 BHK
# 24         1 RK
# 25        3 BHK
# 26        2 BHK
# 27        3 BHK
# 28        2 BHK
# 29        3 BHK
# 30        4 BHK
# 31        3 BHK
# 32        3 BHK
# 33        3 BHK
# 34        3 BHK
# 35        2 BHK
# 36        2 BHK
# 37        3 BHK
# 38        3 BHK
# 39        2 BHK
# 40        2 BHK
# 41        3 BHK
# 42        1 BHK
# 43    1 Bedroom
# 44        2 BHK
# 45    8 Bedroom
# 46        2 BHK
# 47        2 BHK
# 48    2 Bedroom
# 49        2 BHK
# Name: size, dtype: object

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# 5      Super built-up  Area  Ready To Move                Whitefield
# 6      Super built-up  Area         18-May          Old Airport Road
# 7      Super built-up  Area  Ready To Move              Rajaji Nagar
# 8      Super built-up  Area  Ready To Move              Marathahalli
# 9                Plot  Area  Ready To Move              Gandhi Bazar
# 10     Super built-up  Area         18-Feb                Whitefield
# 11               Plot  Area  Ready To Move                Whitefield
# 12     Super built-up  Area  Ready To Move        7th Phase JP Nagar
# ...

# %%
df=df.sort_values(by='price')
df1=df['price'].head(10000)
df1.hist(bins=50)

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.area_type.value_counts()
# Out:
# Super built-up  Area    8790
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              87
# Name: area_type, dtype: int64

# %%
x=df.area_type.value_counts().keys().tolist()
y=df.area_type.value_counts().tolist()

# %%
x
y
# Out:
# [8790, 2418, 2025, 87]

# %%
x
# Out:
# ['Super built-up  Area', 'Built-up  Area', 'Plot  Area', 'Carpet  Area']

# %%
y
# Out:
# [8790, 2418, 2025, 87]

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(x,y)
plt.show()

# %%
# !pip install matplotlib
# Out:
# Requirement not upgraded as not directly required: matplotlib in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages
# Requirement not upgraded as not directly required: numpy>=1.7.1 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from matplotlib)
# Requirement not upgraded as not directly required: six>=1.10 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from matplotlib)
# Requirement not upgraded as not directly required: python-dateutil>=2.0 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from matplotlib)
# Requirement not upgraded as not directly required: pytz in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from matplotlib)
# Requirement not upgraded as not directly required: cycler>=0.10 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from matplotlib)
# ...

# %%
df.isnull().sum(axis=0)
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
fix_area_type={'Super built-up  Area':0,'Built-up  Area':1,'Plot  Area':2,'Carpet  Area':3}
df['area_type']=df.area_type.map(fix_area_type)

# %%
df.head(10)
# Out:
#    area_type   availability                  location       size  society  \
# 0          0         19-Dec  Electronic City Phase II      2 BHK  Coomee
# 1          2  Ready To Move          Chikka Tirupathi  4 Bedroom  Theanmp
# 2          1  Ready To Move               Uttarahalli      3 BHK      NaN
# 3          0  Ready To Move        Lingadheeranahalli      3 BHK  Soiewre
# 4          0  Ready To Move                  Kothanur      2 BHK      NaN
# 5          0  Ready To Move                Whitefield      2 BHK  DuenaTa
# 6          0         18-May          Old Airport Road      4 BHK  Jaades
# 7          0  Ready To Move              Rajaji Nagar      4 BHK  Brway G
# 8          0  Ready To Move              Marathahalli      3 BHK      NaN
# 9          2  Ready To Move              Gandhi Bazar  6 Bedroom      NaN
#
#   total_sqft  bath  balcony   price
# 0       1056   2.0      1.0   39.07
# 1       2600   5.0      3.0  120.00
# 2       1440   2.0      3.0   62.00
# ...

# %%
df.availability.value_counts()
# Out:
# Ready To Move           10581
# 18-Dec                    307
# 18-May                    295
# 18-Apr                    271
# 18-Aug                    200
# 19-Dec                    185
# 18-Jul                    143
# 18-Mar                    131
# 18-Jun                     99
# 20-Dec                     98
# 21-Dec                     93
# 19-Mar                     88
# 18-Feb                     62
# 18-Nov                     47
# 18-Jan                     43
# 18-Sep                     41
# 19-Jun                     40
# 19-Jan                     39
# 18-Oct                     39
# 19-Jul                     36
# 17-Dec                     29
# 20-Jan                     24
# 17-Oct                     21
# 19-Sep                     21
# 22-Jun                     19
# 19-Aug                     18
# 21-Jun                     17
# 20-Aug                     16
# 19-Apr                     16
# Immediate Possession       16
#                         ...
# ...

# %%
def replace_avail(my_string):
    if my_string=="Ready To Move":
        return 0
    elif my_string=="Immediate Possesion":
        return 1
    else:
        return 2

# %%
df['availability']=df.availability.apply(replace_avail)

# %%
df.head(50)
# Out:
#     area_type  availability                  location       size  society  \
# 0           0             2  Electronic City Phase II      2 BHK  Coomee
# 1           2             0          Chikka Tirupathi  4 Bedroom  Theanmp
# 2           1             0               Uttarahalli      3 BHK      NaN
# 3           0             0        Lingadheeranahalli      3 BHK  Soiewre
# 4           0             0                  Kothanur      2 BHK      NaN
# 5           0             0                Whitefield      2 BHK  DuenaTa
# 6           0             2          Old Airport Road      4 BHK  Jaades
# 7           0             0              Rajaji Nagar      4 BHK  Brway G
# 8           0             0              Marathahalli      3 BHK      NaN
# 9           2             0              Gandhi Bazar  6 Bedroom      NaN
# 10          0             2                Whitefield      3 BHK      NaN
# 11          2             0                Whitefield  4 Bedroom  Prrry M
# ...

# %%
import pandas as pd

# %%
import re

# %%
text="10Hello world10"
x=re.split("\d*.*\d",text)
print(x)
# Out:
# ['', '']

# %%
def area_conversion(data):
    try:
        return float(data)
    except:
        thislist =['sq. meter','sq. yards','perch','acres','cents','guntha','grounds']
        conversion=[10.7639, 9.0, 272.25, 43560, 435.61545, 1089.0, 2400.0]
        x=re.split("(\d*.*\d)",data)
        try:
            number=float(x[1])
        except:
            return None
        area_type=x[2].lower()
        index_area = thislist.index(area_type)
        return number*conversion[index_area]
    
df['total_sqft']=df.total_sqft.apply(area_conversion)
df.head(50)
# Out:
#     area_type  availability                  location       size  society  \
# 0           0             2  Electronic City Phase II      2 BHK  Coomee
# 1           2             0          Chikka Tirupathi  4 Bedroom  Theanmp
# 2           1             0               Uttarahalli      3 BHK      NaN
# 3           0             0        Lingadheeranahalli      3 BHK  Soiewre
# 4           0             0                  Kothanur      2 BHK      NaN
# 5           0             0                Whitefield      2 BHK  DuenaTa
# 6           0             2          Old Airport Road      4 BHK  Jaades
# 7           0             0              Rajaji Nagar      4 BHK  Brway G
# 8           0             0              Marathahalli      3 BHK      NaN
# 9           2             0              Gandhi Bazar  6 Bedroom      NaN
# 10          0             2                Whitefield      3 BHK      NaN
# 11          2             0                Whitefield  4 Bedroom  Prrry M
# ...

# %%
text="1657sq.Meter"
y=text.split("@")
print(y)
x=re.split("\d*.*\d",text)
print(x)
# Out:
# ['1657sq.Meter']
# ['', 'sq.Meter']

# %%
text="1657sq.Meter"
y=text.split("@")
print(y)
x=re.split("\d*.*\d",text)
print(x)
# Out:
# ['1657sq.Meter']
# ['', 'sq.Meter']

# %%
df=df.drop(columns='society',axis=1)

# %%
df=df.dropna()

# %%
df.tail()
# Out:
#        area_type  availability               location       size  total_sqft  \
# 13314          0             0      Green Glen Layout      3 BHK      1715.0
# 13315          1             0             Whitefield  5 Bedroom      3453.0
# 13317          1             0  Raja Rajeshwari Nagar      2 BHK      1141.0
# 13318          0             2        Padmanabhanagar      4 BHK      4689.0
# 13319          0             0           Doddathoguru      1 BHK       550.0
#
#        bath  balcony  price
# 13314   3.0      3.0  112.0
# 13315   4.0      0.0  231.0
# 13317   2.0      1.0   60.0
# 13318   4.0      1.0  488.0
# 13319   1.0      1.0   17.0

# %%
df.shape
df.head()
# Out:
#    area_type  availability                  location       size  total_sqft  \
# 0          0             2  Electronic City Phase II      2 BHK      1056.0
# 1          2             0          Chikka Tirupathi  4 Bedroom      2600.0
# 2          1             0               Uttarahalli      3 BHK      1440.0
# 3          0             0        Lingadheeranahalli      3 BHK      1521.0
# 4          0             0                  Kothanur      2 BHK      1200.0
#
#    bath  balcony   price
# 0   2.0      1.0   39.07
# 1   5.0      3.0  120.00
# 2   2.0      3.0   62.00
# 3   3.0      1.0   95.00
# 4   2.0      1.0   51.00

# %%
df=df.drop(columns='area_type',axis=1)
df=df.drop(columns='availability',axis=1)

# %%
import seaborn as sns
correlation_matrix=df.corr()
sns.heatmap(correlation_matrix, cbar= True, annot= True, square = True)
